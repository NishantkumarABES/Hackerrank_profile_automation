# %%
# Requied pakages:
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
id_data = pd.read_csv("Test_data.csv")
id_data.head()
# Out:
#    Unnamed: 0  SNo       Unnamed: 1            Unnamed: 2        Unnamed: 3  \
# 0           0  SNo          Roll No                  Name     Hackerrank Id
# 1           1  1.0  2200320100001.0         AARYAN PANDEY  @aaryanpandey237
# 2           2  2.0  2200320100002.0          AAYUSH KUMAR  CSEA 220B0101018
# 3           3  3.0  2200320100003.0  ABHISHEK VISHWAKARMA      abhivish1509
# 4           4  4.0  2200320100004.0           ADARSH MANI   CSEA_22B0101152
#
#    Unnamed: 4  Unnamed: 5 Day 1  Unnamed: 7  Unnamed: 8  ...    Codechef   \
# 0         NaN         NaN   1.0         2.0         3.0  ...  Star Rating
# 1         NaN         NaN   1.0         1.0         1.0  ...          NaN
# 2         NaN         NaN   1.0         1.0         1.0  ...          NaN
# 3         NaN         NaN   1.0         1.0         1.0  ...          NaN
# 4         NaN         NaN   1.0         1.0         1.0  ...          NaN
#
#            Unnamed: 237  Status of  Basic Certification  \
# ...
